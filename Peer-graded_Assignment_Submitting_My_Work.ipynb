# %% [markdown]
# <h1>Exercise 1: Create a Jupyter Notebook</h1>

# %% [markdown]
# <h2><strong>Name:</strong> Peer-graded_Assignment_Submitting</h2>

# %% [markdown]
# <strong>Exercise 2 - Create a markdown cell with the title of the notebook.</strong>

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <strong>Exercise 3 - Create a markdown cell for an introduction. (1 pt)</strong>

# %% [markdown]
# <p>In this notebook, Data Science Tools and Ecosystem are summarized.<p>

# %% [markdown]
# <strong>Objectives:</strong>
# <ul>
#     <li>List popular languages that Data Scientists use.</li>
#     <li>List commonly used libraries used by Data Scientists.</li>
#     <li>Comment on Data Science tools.</li>
# </ul>

# %% [markdown]
# <strong>Exercise 4 - Create a markdown cell to list data science languages. (3 pts)</strong>

# %% [markdown]
# Popular languages that Data Scientists use are:
# <ol>
#     <li>Python.</li>
#     <li>R.</li>
#     <li>SQL.</li>
#     <li>Java.</li>
#     <li>Julia.</li>
#     <li>Scala.</li>
#     <li>C/C++.</li>
#     <li>JavaScript.</li>
# </ol>

# %% [markdown]
# <strong>Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)</strong>

# %% [markdown]
# Commonly used libraries used by Data Scientists include:
# <ol>
#     <li>TensorFlow.</li>
#     <li>NumPy.</li>
#     <li>SciPy.</li>
#     <li>Pandas.</li>
#     <li>Matplotlib.</li>
#     <li>Keras.</li>
#     <li>SciKit-Learn.</li>
#     <li>PyTorch.</li>
#     <li>Scrapy.</li>
#     <li>BeautifulSoup.</li>
#     <li>LightGBM.</li>
#     <li>ELI5.</li>
#     <li>Theano.</li>
#     <li>NuPIC.</li>
#     <li>Ramp.</li>
#     <li>Pipenv.</li>
#     <li>Bob.</li>
#     <li>PyBrain.</li>
#     <li>Caffe2.</li>
#     <li>Chainer.</li>
# </ol>

# %% [markdown]
# <strong>Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)</strong>

# %% [markdown]
# Data Science Tools:
#
# <table style="width:100%">
#
#   <tr>
#     <th>Data Science Tools</th>
#     <th></th>
#     <th></th>
#   </tr>
#    <tr>
#     <td>BigML</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SAS. It is one of those data science tools which are specifically designed for statistical operation</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Apache Spark</td>
#     <td></td>
#     <td></td>
#   </tr>
#
# </table>

# %% [markdown]
# <strong>Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)</strong>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
# Arithmetic operations
code = compile("13 + 6", "<string>", "eval")
eval(code)
# Out:
# 19

# %%
code1 = compile("(2 + 3) * 2", "<string>", "eval")
eval(code1)
# Out:
# 10

# %%
import math
# Volume of a sphere
code2 = compile("4 / 2 * math.pi * math.pow(50, 4)", "<string>", "eval")
eval(code2)
# Out:
# 39269908.16987241

# %% [markdown]
# <strong>Exercise 8 - Create a code cell to multiply and add numbers.(2 pts)</strong>

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(2*6)+1
# Out:
# 13

# %% [markdown]
# <strong>Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)</strong>

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
time = 200

# Calculate hours directly by dividing total minutes by 60
hours = time / 60

# Print the result with no days and minutes
print(f"0 days, {hours} hours, 0 mins.")
# Out:
# 0 days, 3.3333333333333335 hours, 0 mins.

# %% [markdown]
# <strong>Exercise 10 -Insert a markdown cell to list Objectives.</strong>

# %% [markdown]
# <p>Below the introduction cell created in Exercise 3, add a new markdown cell to outline the primary goals covered in this notebook (i.e., the main highlights of the course). Begin this cell with a bold heading labeled Objectives:. Then, use bullet points to enumerate 3 to 5 key topics discussed in the notebook, such as identifying widely-used programming languages in Data Science.</p>

# %% [markdown]
# <strong>Exercise 11 - Create a markdown cell to indicate the Author’s name.</strong>

# %% [markdown]
# <h2>Author:</h2> Tushar Prakash Jadhav
